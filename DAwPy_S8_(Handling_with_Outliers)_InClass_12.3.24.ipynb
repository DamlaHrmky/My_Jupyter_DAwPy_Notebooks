# %% [markdown]
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# <img src=https://i.ibb.co/6gCsHd6/1200px-Pandas-logo-svg.png width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:150%; text-align:center; border-radius:10px 10px;">Session - 08</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#4d77cf; font-size:200%; text-align:center; border-radius:10px 10px;">Handling with Outliers</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [IMPORTING LIBRARIES NEEDED IN THIS NOTEBOOK](#0)
# * [HANDLING WITH OUTLIERS](#1)
# * [CATCHING & DETECTING OUTLIERS](#2)
# * [REMOVING THE OUTLIERS](#3)
# * [LIMITATION & TRANSFORMATION OF THE OUTLIERS](#4)
# * [THE END OF THE SESSION - 07](#5)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Libraries Needed in This Notebook</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Outliers</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ### What is Outlier? [Source](https://statisticsbyjim.com/basics/remove-outliers/#:~:text=Outliers%20are%20unusual%20values%20in,what%20to%20do%20with%20them.)
#
# In general, <b>``Outliers``</b> are **unusual values** in your dataset, and they can **distort statistical analyses and violate their assumptions**. ... Outliers increase the variability in your data, which decreases statistical power. Consequently, excluding outliers can cause your results to become statistically significant. Outliers can have a disproportionate effect on statistical results, such as the mean, which can result in misleading interpretations. In this case, the mean value makes it seem that the data values are higher than they really are.

# %% [markdown]
# ### Most common causes of outliers on a data set [Source](https://towardsdatascience.com/a-brief-overview-of-outlier-detection-techniques-1e0b2c19e561):
#
# - Data entry errors (human errors)
# - Measurement errors (instrument errors)
# - Experimental errors (data extraction or experiment planning/executing errors)
# - Intentional (dummy outliers made to test detection methods)
# - Data processing errors (data manipulation or data set unintended mutations)
# - Sampling errors (extracting or mixing data from wrong or various sources)
# - Natural (not an error, novelties in data)

# %% [markdown]
# ### Guideline for Handling Outliers [Source 01](https://statisticsbyjim.com/basics/remove-outliers/#:~:text=Outliers%20are%20unusual%20values%20in,what%20to%20do%20with%20them.) & [Source 02](https://www.researchgate.net/publication/258174106_Best-Practice_Recommendations_for_Defining_Identifying_and_Handling_Outliers)
#
# - A measurement error or data entry error, correct the error if possible. If you can’t fix it, remove that observation because you know it’s incorrect.
# - Not a part of the population you are studying (i.e., unusual properties or conditions), you can legitimately remove the outlier.
# - A natural part of the population you are studying, you should not remove it.

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Catching and Detecting Outliers</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('diamonds')
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df = df.select_dtypes(include="number")
df
# Out:
#        carat  depth  table  price     x     y     z
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75
# ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   carat   53940 non-null  float64
#  1   depth   53940 non-null  float64
#  2   table   53940 non-null  float64
#  3   price   53940 non-null  int64
#  4   x       53940 non-null  float64
#  5   y       53940 non-null  float64
#  6   z       53940 non-null  float64
# dtypes: float64(6), int64(1)
# memory usage: 2.9 MB

# %%
len(df)
# Out:
# 53940

# %%
df.shape[0]
# Out:
# 53940

# %% [markdown]
# **info about dataset**
# - **carat   :**Carat weight of the diamond
# - **depth % :**The height of a diamond, measured from the culet to the table, divided by its average girdle diameter
# - **table % :**The width of the diamond's table expressed as a percentage of its average diameter
# - **price   :**the price of the diamond
# - **x       :**length mm
# - **y       :**width mm
# - **z       :**higth mm

# %% [markdown]
# ### Detecting Outliers with Graphs

# %%
# you don't need to know how this plotting happens.
# just focus on quarters
# remember Statistics lesson IQR

plt.figure(figsize = (12, 6))
sns.boxplot(x = df['table']);

# %%
plt.figure(figsize = (10, 4))
sns.histplot(df.table, bins = 50, kde = False);

# %%
df.table.sort_values(ascending=True)
# Out:
# 11368    43.0
# 35633    44.0
# 5979     49.0
# 22701    49.0
# 25179    50.0
#          ...
# 52861    73.0
# 52860    73.0
# 51342    76.0
# 50773    79.0
# 24932    95.0
# Name: table, Length: 53940, dtype: float64

# %%
df.table.sort_values(ascending=True).tail(10)
# Out:
# 23067    70.0
# 43705    70.0
# 44938    71.0
# 51391    73.0
# 49375    73.0
# 52861    73.0
# 52860    73.0
# 51342    76.0
# 50773    79.0
# 24932    95.0
# Name: table, dtype: float64

# %%
df.table.sort_values(ascending=True).tail(20)
# Out:
# 52474    69.0
# 91       69.0
# 40211    69.0
# 777      70.0
# 47149    70.0
# 52393    70.0
# 314      70.0
# 51026    70.0
# 52092    70.0
# 42256    70.0
# 23067    70.0
# 43705    70.0
# 44938    71.0
# 51391    73.0
# 49375    73.0
# 52861    73.0
# 52860    73.0
# 51342    76.0
# 50773    79.0
# 24932    95.0
# Name: table, dtype: float64

# %%
df.table.sort_values(ascending=True).tail(8).index
# Out:
# Index([44938, 51391, 49375, 52861, 52860, 51342, 50773, 24932], dtype='int64')

# %%
tail_index = df.table.sort_values(ascending=True).tail(8).index
tail_index
# Out:
# Index([44938, 51391, 49375, 52861, 52860, 51342, 50773, 24932], dtype='int64')

# %%
# df.loc[[44938, 51391, 49375, 52861, 52860, 51342, 50773, 24932]]

df.loc[tail_index]
# Out:
#        carat  depth  table  price     x     y     z
# 44938   0.68   58.0   71.0   1633  5.85  5.70  3.35
# 51391   0.71   55.6   73.0   2368  6.01  5.96  3.33
# 49375   0.70   62.0   73.0   2100  5.65  5.54  3.47
# 52861   0.50   79.0   73.0   2579  5.21  5.18  4.09
# 52860   0.50   79.0   73.0   2579  5.21  5.18  4.09
# 51342   0.79   65.3   76.0   2362  5.52  5.13  3.35
# 50773   0.81   68.8   79.0   2301  5.26  5.20  3.58
# 24932   2.01   58.6   95.0  13387  8.32  8.31  4.87

# %% [markdown]
# ### Detecting Outliers with Tukey's Fences | Tukey's Rule

# %% [markdown]
# **- First way** of specifying **``Q1 & Q3``** is using the **``.quantile()``** method

# %%
Q1 = df["table"].quantile(0.25)
Q3 = df["table"].quantile(0.75)

IQR = Q3 - Q1

# %%
Q1
# Out:
# 56.0

# %%
Q3
# Out:
# 59.0

# %%
IQR
# Out:
# 3.0

# %% [markdown]
# **- Second way** of specifying **``Q1 & Q3``** is using the **``.describe()``** method

# %%
df.table.describe()
# Out:
# count    53940.000000
# mean        57.457184
# std          2.234491
# min         43.000000
# 25%         56.000000
# 50%         57.000000
# 75%         59.000000
# max         95.000000
# Name: table, dtype: float64

# %%
Q1 = df.table.describe().loc["25%"]
Q3 = df.table.describe().loc["75%"]
IQR = Q3 - Q1
IQR
# Out:
# 3.0

# %% [markdown]
# **- Third way** of specifying **IQR** is using the **scipy.stats.iqr** method

# %%
from scipy import stats

IQR = stats.iqr(df.table)
IQR
# Out:
# 3.0

# %%
lower_lim = Q1 - 1.5 * IQR
upper_lim = Q3 + 1.5 * IQR

# %%
lower_lim
# Out:
# 51.5

# %%
upper_lim
# Out:
# 63.5

# %%
(df.table < lower_lim)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 53935    False
# 53936    False
# 53937    False
# 53938    False
# 53939    False
# Name: table, Length: 53940, dtype: bool

# %%
(df.table < lower_lim).sum()
# Out:
# 16

# %%
(df.table > upper_lim).sum()
# Out:
# 589

# %%
df.table
# Out:
# 0        55.0
# 1        61.0
# 2        65.0
# 3        58.0
# 4        58.0
#          ...
# 53935    57.0
# 53936    55.0
# 53937    60.0
# 53938    58.0
# 53939    55.0
# Name: table, Length: 53940, dtype: float64

# %%
df.table[(df.table < lower_lim) | (df.table > upper_lim)]
# Out:
# 2        65.0
# 91       69.0
# 145      64.0
# 219      64.0
# 227      67.0
#          ...
# 53695    65.0
# 53697    65.0
# 53756    64.0
# 53757    64.0
# 53785    65.0
# Name: table, Length: 605, dtype: float64

# %%
df.table[(df.table < lower_lim) | (df.table > upper_lim)].count()
# Out:
# 605

# %%
df.table[~((df.table < lower_lim) | (df.table > upper_lim))]
# Out:
# 0        55.0
# 1        61.0
# 3        58.0
# 4        58.0
# 5        57.0
#          ...
# 53935    57.0
# 53936    55.0
# 53937    60.0
# 53938    58.0
# 53939    55.0
# Name: table, Length: 53335, dtype: float64

# %%
df.table[~((df.table < lower_lim) | (df.table > upper_lim))].count()
# Out:
# 53335

# %%
df.loc[((df.table < lower_lim) | (df.table > upper_lim))]
# Out:
#        carat  depth  table  price     x     y     z
# 2       0.23   56.9   65.0    327  4.05  4.07  2.31
# 91      0.86   55.1   69.0   2757  6.45  6.33  3.52
# 145     0.70   62.1   64.0   2767  5.62  5.65  3.50
# 219     0.53   57.5   64.0   2782  5.34  5.37  3.08
# 227     0.84   55.1   67.0   2782  6.39  6.20  3.47
# ...      ...    ...    ...    ...   ...   ...   ...
# 53695   0.75   59.7   65.0   2717  5.85  5.80  3.48
# 53697   0.70   64.5   65.0   2717  5.52  5.45  3.54
# 53756   0.84   55.6   64.0   2724  6.42  6.32  3.54
# 53757   0.72   55.4   64.0   2724  6.06  5.97  3.34
# 53785   0.89   64.3   65.0   2728  6.00  5.95  3.84
#
# [605 rows x 7 columns]

# %%
df.table[(df.table >= lower_lim) & (df.table <= upper_lim)]
# Out:
# 0        55.0
# 1        61.0
# 3        58.0
# 4        58.0
# 5        57.0
#          ...
# 53935    57.0
# 53936    55.0
# 53937    60.0
# 53938    58.0
# 53939    55.0
# Name: table, Length: 53335, dtype: float64

# %%
df.table[(df.table >= lower_lim) & (df.table <= upper_lim)].count
# Out:
# <bound method Series.count of 0        55.0
# 1        61.0
# 3        58.0
# 4        58.0
# 5        57.0
#          ...
# 53935    57.0
# 53936    55.0
# 53937    60.0
# 53938    58.0
# 53939    55.0
# Name: table, Length: 53335, dtype: float64>

# %%
df.loc[(df.table >= lower_lim) & (df.table <= upper_lim)]
# Out:
#        carat  depth  table  price     x     y     z
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24   62.8   57.0    336  3.94  3.96  2.48
# ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53335 rows x 7 columns]

# %%
df.table[(df.table >= lower_lim) & (df.table <= upper_lim)].index
# Out:
# Index([    0,     1,     3,     4,     5,     6,     7,     8,     9,    10,
#        ...
#        53930, 53931, 53932, 53933, 53934, 53935, 53936, 53937, 53938, 53939],
#       dtype='int64', length=53335)

# %%
df.loc[df.table[(df.table >= lower_lim) & (df.table <= upper_lim)].index]
# Out:
#        carat  depth  table  price     x     y     z
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24   62.8   57.0    336  3.94  3.96  2.48
# ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53335 rows x 7 columns]

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Removing the Outliers</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df.loc[(df.table < lower_lim) | (df.table > upper_lim)]
# Out:
#        carat  depth  table  price     x     y     z
# 2       0.23   56.9   65.0    327  4.05  4.07  2.31
# 91      0.86   55.1   69.0   2757  6.45  6.33  3.52
# 145     0.70   62.1   64.0   2767  5.62  5.65  3.50
# 219     0.53   57.5   64.0   2782  5.34  5.37  3.08
# 227     0.84   55.1   67.0   2782  6.39  6.20  3.47
# ...      ...    ...    ...    ...   ...   ...   ...
# 53695   0.75   59.7   65.0   2717  5.85  5.80  3.48
# 53697   0.70   64.5   65.0   2717  5.52  5.45  3.54
# 53756   0.84   55.6   64.0   2724  6.42  6.32  3.54
# 53757   0.72   55.4   64.0   2724  6.06  5.97  3.34
# 53785   0.89   64.3   65.0   2728  6.00  5.95  3.84
#
# [605 rows x 7 columns]

# %%
df.loc[(df.table < lower_lim) | (df.table > upper_lim)].index
# Out:
# Index([    2,    91,   145,   219,   227,   239,   296,   314,   356,   359,
#        ...
#        53226, 53503, 53542, 53577, 53660, 53695, 53697, 53756, 53757, 53785],
#       dtype='int64', length=605)

# %%
outlier_index = df.loc[(df.table < lower_lim) | (df.table > upper_lim)].index
outlier_index
# Out:
# Index([    2,    91,   145,   219,   227,   239,   296,   314,   356,   359,
#        ...
#        53226, 53503, 53542, 53577, 53660, 53695, 53697, 53756, 53757, 53785],
#       dtype='int64', length=605)

# %%
not_outliers = (df.table >= lower_lim) & (df.table <= upper_lim)
not_outliers
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 53935     True
# 53936     True
# 53937     True
# 53938     True
# 53939     True
# Name: table, Length: 53940, dtype: bool

# %%
cleaned_df = df[not_outliers]
cleaned_df
# Out:
#        carat  depth  table  price     x     y     z
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24   62.8   57.0    336  3.94  3.96  2.48
# ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53335 rows x 7 columns]

# %%
df.loc[~((df.table < lower_lim) | (df.table > upper_lim))]
# Out:
#        carat  depth  table  price     x     y     z
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24   62.8   57.0    336  3.94  3.96  2.48
# ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53335 rows x 7 columns]

# %%
df_cleaned = df.loc[~((df.table < lower_lim) | (df.table > upper_lim))]
df_cleaned
# Out:
#        carat  depth  table  price     x     y     z
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24   62.8   57.0    336  3.94  3.96  2.48
# ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53335 rows x 7 columns]

# %%
df
# Out:
#        carat  depth  table  price     x     y     z
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75
# ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 7 columns]

# %%
df.drop(outlier_index, axis=0)
# Out:
#        carat  depth  table  price     x     y     z
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24   62.8   57.0    336  3.94  3.96  2.48
# ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53335 rows x 7 columns]

# %%
plt.figure(figsize = (8, 3))
sns.boxplot(x = cleaned_df.table);

# %%
sns.histplot(cleaned_df.table, bins=20, kde=False);

# %%
df.table.describe()
# Out:
# count    53940.000000
# mean        57.457184
# std          2.234491
# min         43.000000
# 25%         56.000000
# 50%         57.000000
# 75%         59.000000
# max         95.000000
# Name: table, dtype: float64

# %%
cleaned_df.table.describe()
# Out:
# count    53335.000000
# mean        57.373404
# std          2.074349
# min         51.600000
# 25%         56.000000
# 50%         57.000000
# 75%         59.000000
# max         63.500000
# Name: table, dtype: float64

# %%
df.table.describe().index
# Out:
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'], dtype='object')

# %%
df.table.describe().values
# Out:
# array([5.39400000e+04, 5.74571839e+01, 2.23449056e+00, 4.30000000e+01,
#        5.60000000e+01, 5.70000000e+01, 5.90000000e+01, 9.50000000e+01])

# %%
compare = pd.DataFrame(df.table.describe().values, index = df.table.describe().index, columns = ["original"])

compare
# Out:
#            original
# count  53940.000000
# mean      57.457184
# std        2.234491
# min       43.000000
# 25%       56.000000
# 50%       57.000000
# 75%       59.000000
# max       95.000000

# %%
compare["clean"] = cleaned_df.table.describe().values
compare
# Out:
#            original         clean
# count  53940.000000  53335.000000
# mean      57.457184     57.373404
# std        2.234491      2.074349
# min       43.000000     51.600000
# 25%       56.000000     56.000000
# 50%       57.000000     57.000000
# 75%       59.000000     59.000000
# max       95.000000     63.500000

# %%
pd.DataFrame([df.table.describe()])
# Out:
#          count       mean       std   min   25%   50%   75%   max
# table  53940.0  57.457184  2.234491  43.0  56.0  57.0  59.0  95.0

# %%
pd.DataFrame([df.table.describe(), cleaned_df.table.describe()])
# Out:
#          count       mean       std   min   25%   50%   75%   max
# table  53940.0  57.457184  2.234491  43.0  56.0  57.0  59.0  95.0
# table  53335.0  57.373404  2.074349  51.6  56.0  57.0  59.0  63.5

# %%
pd.DataFrame([df.table.describe(), cleaned_df.table.describe()], 
            index=["original", "cleaned"])
# Out:
#             count       mean       std   min   25%   50%   75%   max
# original  53940.0  57.457184  2.234491  43.0  56.0  57.0  59.0  95.0
# cleaned   53335.0  57.373404  2.074349  51.6  56.0  57.0  59.0  63.5

# %%
pd.DataFrame([df.table.describe(), cleaned_df.table.describe()], 
            index=["original", "cleaned"]).transpose()
# Out:
#            original       cleaned
# count  53940.000000  53335.000000
# mean      57.457184     57.373404
# std        2.234491      2.074349
# min       43.000000     51.600000
# 25%       56.000000     56.000000
# 50%       57.000000     57.000000
# 75%       59.000000     59.000000
# max       95.000000     63.500000

# %%
pd.DataFrame([df.table.describe(), cleaned_df.table.describe()], index=['original', 'clean']).T

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Limitation & Transformation of the Outliers</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ## Limitation using ``.winsorize()`` method
#
# With winsorizing, any value of a variable above or below a percentile k on each side of the variables’ distribution is replaced with the value of the k-th percentile itself. For example, if k=5, all observations above the 95th percentile are recoded to the value of the 95th percentile, and values below the 5th percent are recoded, respectively [Source 01](https://towardsdatascience.com/detecting-and-treating-outliers-in-python-part-3-dcb54abaf7b0) & [Source 02](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.mstats.winsorize.html).

# %%
from scipy.stats.mstats import winsorize

# %%
df
# Out:
#        carat  depth  table  price     x     y     z
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75
# ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 7 columns]

# %%
winsorize(df.table, (0.02, 0.05))
# Out:
# masked_array(data=[55., 61., 61., ..., 60., 58., 55.],
#              mask=False,
#        fill_value=1e+20)

# %%
len(df.table[df.table < lower_lim])
# Out:
# 16

# %%
a = len(df.table[df.table < lower_lim]) / len(df)
a
# Out:
# 0.00029662588060808305

# %%
len(df.table[df.table > upper_lim])
# Out:
# 589

# %%
b = len(df.table[df.table > upper_lim]) / len(df.table)
b
# Out:
# 0.010919540229885057

# %%
winsorize(df.table, (a, b))
# Out:
# masked_array(data=[55. , 61. , 63.5, ..., 60. , 58. , 55. ],
#              mask=False,
#        fill_value=1e+20)

# %%
table_win = winsorize(df.table, (a, b))

# %%
plt.figure(figsize = (8, 3))

sns.boxplot(x=table_win);

# %%
sns.displot(table_win, bins=10, kde=False);
# Out:
# C:\Users\edwin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
table_win
# Out:
# masked_array(data=[55. , 61. , 63.5, ..., 60. , 58. , 55. ],
#              mask=False,
#        fill_value=1e+20)

# %%
table_win_ser = pd.Series(table_win)
table_win_ser
# Out:
# 0        55.0
# 1        61.0
# 2        63.5
# 3        58.0
# 4        58.0
#          ...
# 53935    57.0
# 53936    55.0
# 53937    60.0
# 53938    58.0
# 53939    55.0
# Length: 53940, dtype: float64

# %%
len(df)
# Out:
# 53940

# %%
pd.DataFrame([df.table.describe(), table_win_ser.describe()], index=['original', 'clean']).T
# Out:
# C:\Users\edwin\anaconda3\Lib\site-packages\numpy\lib\function_base.py:4737: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
#            original         clean
# count  53940.000000  53940.000000
# mean      57.457184     57.438591
# std        2.234491      2.161059
# min       43.000000     51.600000
# 25%       56.000000     56.000000
# 50%       57.000000     57.000000
# 75%       59.000000     59.000000
# max       95.000000     63.500000

# %%
upper_lim, lower_lim
# Out:
# (63.5, 51.5)

# %%
df.table.sort_values().head(20)
# Out:
# 11368    43.0
# 35633    44.0
# 5979     49.0
# 22701    49.0
# 25179    50.0
# 7418     50.0
# 3238     50.1
# 45798    51.0
# 33586    51.0
# 46040    51.0
# 26387    51.0
# 3979     51.0
# 8853     51.0
# 4150     51.0
# 1515     51.0
# 47630    51.0
# 24815    51.6
# 15858    52.0
# 25607    52.0
# 5144     52.0
# Name: table, dtype: float64

# %%
table_win_ser.sort_values().head(20)
# Out:
# 11368    51.6
# 25179    51.6
# 45798    51.6
# 33586    51.6
# 46040    51.6
# 26387    51.6
# 3979     51.6
# 8853     51.6
# 35633    51.6
# 22701    51.6
# 24815    51.6
# 1515     51.6
# 5979     51.6
# 3238     51.6
# 47630    51.6
# 4150     51.6
# 7418     51.6
# 5144     52.0
# 33408    52.0
# 26431    52.0
# dtype: float64

# %%
table_win_ser[table_win_ser == 51.6].count()
# Out:
# 17

# %%
table_win_ser[table_win_ser == 63.5].count()
# Out:
# 590

# %% [markdown]
# ## Transformation using ``log()`` method
#
# The **``Numpy.log()``** method lets you calculate the mathematical log of any number or array. The numpy.log() is a mathematical function that helps user to calculate Natural logarithm of x where x belongs to all the input array elements.
#
# The natural logarithm log is the inverse of the exponential function, so that log(exp(x)) = x. The natural logarithm is logarithm in base e [Source 01](https://www.geeksforgeeks.org/numpy-log-python/#:~:text=The%20numpy.,is%20log%20in%20base%20e.) & [Source 02](https://numpy.org/doc/stable/reference/generated/numpy.log.html).

# %%
df
# Out:
#        carat  depth  table  price     x     y     z
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75
# ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 7 columns]

# %%
plt.figure(figsize = (10, 3))
sns.boxplot(x=df.carat);

# %%
sns.histplot(df.carat, bins=20, kde=False);

# %%
np.log(df.carat)
# Out:
# 0       -1.469676
# 1       -1.560648
# 2       -1.469676
# 3       -1.237874
# 4       -1.171183
#            ...
# 53935   -0.328504
# 53936   -0.328504
# 53937   -0.356675
# 53938   -0.150823
# 53939   -0.287682
# Name: carat, Length: 53940, dtype: float64

# %%
plt.figure(figsize = (10, 3))
sns.boxplot(x = np.log(df.carat));

# %%
sns.histplot(np.log(df.carat),  bins=10, kde=False);

# %%
df["carat_log"] = np.log(df.carat)
df
# Out:
#        carat  depth  table  price     x     y     z  carat_log
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43  -1.469676
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31  -1.560648
# 2       0.23   56.9   65.0    327  4.05  4.07  2.31  -1.469676
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63  -1.237874
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75  -1.171183
# ...      ...    ...    ...    ...   ...   ...   ...        ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50  -0.328504
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61  -0.328504
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56  -0.356675
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74  -0.150823
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64  -0.287682
#
# [53940 rows x 8 columns]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(8, 4))

sns.boxplot(x= df.carat, ax=ax1, width=0.4, color='lightblue')
sns.boxplot(x= df.carat_log, ax=ax2, width=0.4, color='lightgreen')

# Eksen etiketleri ekleme:
ax1.set_xlabel('Data : carat')
ax2.set_xlabel('Data : carat_log')

# Başlıkları ekleme:
ax1.set_title('Boxplot for df.carat')
ax2.set_title('Boxplot for carat_log')

# plotları figure içinde düzgün şekilde yerleştirme:
plt.tight_layout();

# %% [markdown]
# ## Removing outliers after log() transformation

# %% [markdown]
# **first method to remove outliers**

# %%
df.carat_log.sort_values().tail()
# Out:
# 25999    1.388791
# 25998    1.388791
# 27130    1.418277
# 27630    1.504077
# 27415    1.611436
# Name: carat_log, dtype: float64

# %%
drop_index = df.carat_log.sort_values().tail(2).index
drop_index
# Out:
# Index([27630, 27415], dtype='int64')

# %%
# df.drop(drop_index)

# %%
df.drop(df.carat_log.sort_values().tail(2).index)
# Out:
#        carat  depth  table  price     x     y     z  carat_log
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43  -1.469676
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31  -1.560648
# 2       0.23   56.9   65.0    327  4.05  4.07  2.31  -1.469676
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63  -1.237874
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75  -1.171183
# ...      ...    ...    ...    ...   ...   ...   ...        ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50  -0.328504
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61  -0.328504
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56  -0.356675
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74  -0.150823
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64  -0.287682
#
# [53938 rows x 8 columns]

# %% [markdown]
# **second method to remove outliers**

# %%
Q1 = df.carat_log.quantile(0.25)
Q3 = df.carat_log.quantile(0.75)

IQR = Q3 - Q1
IQR
# Out:
# 0.9555114450274363

# %%
lower_lim = Q1 - 1.5 * IQR
upper_lim = Q3 + 1.5 * IQR

lower_lim, upper_lim
# Out:
# (-2.3495578994153097, 1.472487880694436)

# %%
(df.carat_log > upper_lim).sum()
# Out:
# 2

# %%
(df.carat_log <= lower_lim).sum()
# Out:
# 0

# %%
df.loc[(df.carat_log > upper_lim)]
# Out:
#        carat  depth  table  price      x      y     z  carat_log
# 27415   5.01   65.5   59.0  18018  10.74  10.54  6.98   1.611436
# 27630   4.50   65.8   58.0  18531  10.23  10.16  6.72   1.504077

# %%
drop_index = df.loc[(df.carat_log > upper_lim)].index
drop_index
# Out:
# Index([27415, 27630], dtype='int64')

# %%
df.drop(drop_index)
# Out:
#        carat  depth  table  price     x     y     z  carat_log
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43  -1.469676
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31  -1.560648
# 2       0.23   56.9   65.0    327  4.05  4.07  2.31  -1.469676
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63  -1.237874
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75  -1.171183
# ...      ...    ...    ...    ...   ...   ...   ...        ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50  -0.328504
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61  -0.328504
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56  -0.356675
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74  -0.150823
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64  -0.287682
#
# [53938 rows x 8 columns]

# %% [markdown]
# **third method to remove outliers**

# %%
not_outliers = (df.carat_log <= upper_lim)

# %%
len(df[not_outliers])
# Out:
# 53938

# %%
cleaned_df = df[not_outliers]
cleaned_df
# Out:
#        carat  depth  table  price     x     y     z  carat_log
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43  -1.469676
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31  -1.560648
# 2       0.23   56.9   65.0    327  4.05  4.07  2.31  -1.469676
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63  -1.237874
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75  -1.171183
# ...      ...    ...    ...    ...   ...   ...   ...        ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50  -0.328504
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61  -0.328504
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56  -0.356675
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74  -0.150823
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64  -0.287682
#
# [53938 rows x 8 columns]

# %% [markdown]
# # Handling outliers using z-score

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Z, z-score'u temsil eder.
#
# X, belirli bir veri noktasının değerini temsil eder.
#
# μ, veri setinin ortalamasını temsil eder.
#
# σ, veri setinin standart sapmasını temsil eder.

# %%
np.random.randn(5,5)
# Out:
# array([[ 0.00935876, -1.27185364,  1.06301784,  0.63739923,  1.26541182],
#        [ 0.27081199, -0.18198567, -1.2220911 ,  0.1519657 , -0.39806742],
#        [ 0.71237959, -0.31073535,  1.89059956,  1.45854533, -0.47924427],
#        [-0.19026916,  0.02885656,  0.24104408,  0.19268341,  1.43127489],
#        [-0.24545271,  0.28373927,  0.72010772, -0.15178455, -0.75924688]])

# %%
from scipy.stats import zscore

# %%
data = {'Value': np.random.normal(loc=50, scale=10, size=1000)}
df_z = pd.DataFrame(data)
df_z
# Out:
#          Value
# 0    43.488565
# 1    49.612697
# 2    68.627542
# 3    22.573099
# 4    58.955471
# ..         ...
# 995  49.246769
# 996  44.523994
# 997  55.713498
# 998  30.370406
# 999  52.684769
#
# [1000 rows x 1 columns]

# %%
sns.histplot(df_z.Value,  bins=10, kde=False);

# %%
outlier_indices = np.random.choice(df_z.index, size=10, replace=False)

# %%
np.random.normal(loc=150, scale=20, size=10)
# Out:
# array([185.39907582, 108.64431789, 148.38193942, 164.75116522,
#        135.18980181, 150.17663883, 164.49233021, 175.46169461,
#        134.00416085, 169.66078194])

# %%
df_z.loc[outlier_indices, 'Value'] = np.random.normal(loc=150, scale=20, size=10)
df_z
# Out:
#          Value
# 0    43.488565
# 1    49.612697
# 2    68.627542
# 3    22.573099
# 4    58.955471
# ..         ...
# 995  49.246769
# 996  44.523994
# 997  55.713498
# 998  30.370406
# 999  52.684769
#
# [1000 rows x 1 columns]

# %%
sns.boxplot(x = df_z['Value']);

# %%
sns.histplot(x = df_z['Value']);

# %%
df_z
# Out:
#          Value
# 0    34.552586
# 1    54.026972
# 2    53.240403
# 3    52.321181
# 4    59.600935
# ..         ...
# 995  59.277342
# 996  66.073911
# 997  38.083492
# 998  41.886485
# 999  48.798732
#
# [1000 rows x 1 columns]

# %%
z_scores_df = zscore(df_z)
z_scores_df
# Out:
#         Value
# 0   -1.208783
# 1    0.213081
# 2    0.155652
# 3    0.088538
# 4    0.620048
# ..        ...
# 995  0.596421
# 996  1.092652
# 997 -0.950984
# 998 -0.673320
# 999 -0.168643
#
# [1000 rows x 1 columns]

# %%
sns.histplot(x = z_scores_df['Value']);

# %%
outliers = z_scores_df[(z_scores_df.Value > 2) | (z_scores_df.Value < -2)]
outliers
# Out:
#         Value
# 45   6.681193
# 82   7.564430
# 87   2.311484
# 212  9.532659
# 337  7.835738
# 387 -2.067414
# 448  7.325810
# 743  2.062403
# 761  5.673144
# 843  5.783214
# 855  6.217873
# 909 -2.505739
# 953  7.138543
# 973  6.723666

# %%
len(outliers)
# Out:
# 14

# %%
df_no_outliers = z_scores_df.drop(outliers.index)
df_no_outliers
# Out:
#         Value
# 0   -1.208783
# 1    0.213081
# 2    0.155652
# 3    0.088538
# 4    0.620048
# ..        ...
# 995  0.596421
# 996  1.092652
# 997 -0.950984
# 998 -0.673320
# 999 -0.168643
#
# [986 rows x 1 columns]

# %%
sns.boxplot(x = df_no_outliers['Value']);

# %%
sns.histplot(x = df_no_outliers['Value']);

# %% [markdown]
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:150%; text-align:center; border-radius:10px 10px;">The End of The Session - 08</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ____
